# %% [markdown]
# # Simple example:

# %%
# %matplotlib inline
import sys
sys.path.insert(0, '../')
import matplotlib.pyplot as plt
import astropy.units as u

from arcesetc import plot_order_counts, plot_order_sn, available_sptypes

# %%
sorted(available_sptypes())
# Out:
# ['F7V',
#  'G0V',
#  'G2V',
#  'G3V',
#  'G5V',
#  'G7V',
#  'G8V',
#  'G9V',
#  'K0V',
#  'K1V',
#  'K2V',
#  'K3V',
#  'K4V',
#  'K5V',
#  'K6V',
#  'K7V',
#  'M0.5V']

# %%
sptype = 'G4V'
wavelength = 6562 * u.Angstrom
exp_time = 30 * u.min
V = 10

plot_order_counts(sptype, wavelength, exp_time, V)
plt.show()

# %%
plot_order_sn(sptype, wavelength, exp_time, V)
plt.show()
